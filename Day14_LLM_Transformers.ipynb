# %% [markdown]
# Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

# %%
from transformers import pipeline
generator=pipeline('text-generation',model='gpt2')
print(generator('India is ',max_length=30))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "India is \xa0the only country where the government is able to deliver a clean, efficient and affordable electricity system. The government has given subsidies to some power providers and has provided them with solar power.\nElectricity has been used for most of the past two decades as a way to provide power to the country's people. Since 1980, the electricity generated by these generators has been used for heating, cooling, heating, and other purposes.\nThe government has also given subsidies to utilities and banks to make efficient use of electricity generation. The government has also provided subsidies for companies to provide services to the public.\nThe power grid is largely based on electricity and is not connected to the grid. The national grid is in charge of maintaining a power grid of over 2.5 times the power capacity of the national grid. In addition, the national grid is connected to the internet and the internet is available for all to see. The electricity generated by the national grid is sold to the national electric utilities and its electricity is provided to the households and businesses of India.\nIndia has two grids: the National Grid and the National Electricity Distribution System. The National Grid is the source of power for nearly all of the country's population, and is controlled by the government. The National Electricity Distribution System is a"}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”


print(generator('The hero enters the ancient forest and discovers',max_length=50))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The hero enters the ancient forest and discovers that the man he was seeing was a demon.\n\nThe hero explains that he is trying to reach a different realm of the universe (the world where the human soul is alive and living).\n\nThe hero then enters the ancient forest and finds that the demon is in the middle of the mountain with an unknown source called the Gorgon.\n\nThe hero then finds a new world and the Gorgon is in the middle of it.\n\nThe hero then goes to the demon and destroys him.\n\nThe hero then enters the ancient forest of the Gorgon and starts talking to the demon.\n\nThe demon is then shocked by what he has seen and attacks the hero.\n\nThe hero then enters the ancient forest of the Gorgon and finds that the demon is a demon.\n\nThe demon then attacks the hero.\n\nThe hero then enters the ancient forest of the Gorgon and finds that the demon is a demon.\n\nThe hero then enters the old world and finds the old world is under attack.\n\nThe hero then enters the old world and finds that the demon is a demon.\n\nThe hero then enters the ancient forest of the Gorgon and finds that the demon is a demon.'}]

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained('bert-base-uncased')
text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

tokenizer=AutoTokenizer.from_pretrained('bert-base-uncased')
text = "I have chest pain and shortness of breath"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %% [markdown]
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

# %%
generator=pipeline('text-generation',model='gpt2')
prompt = "The future of Artificial Intelligence"
print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI researchers.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create AI that is more intelligent than humans.\n\nThe next generation of AI researchers will be able to create'}]
# [{'generated_text': 'The future of Artificial Intelligence is one that focuses on the development of "smart" machine learning in a way that is easier to understand, more precise, and more accurate than traditional machine learning methods.\n\nMachine learning is a new, exciting field that has been embraced by many industries, including education, healthcare, and education and marketing. In the past few decades, many companies and academia have started to develop more advanced and more advanced AI in parallel with machine learning methods.\n\nMachine Learning and AI\n\nThe present, evolving trend in AI is driven by the emergence of AI technologies. AI, for example, has become increasingly well understood as a tool for understanding human behavior and provides unprecedented insights into our behavior and behaviours.\n\nThe world is constantly changing, and as we continue to learn, we will have to adapt and adapt to change, as well as continue to learn. When I was a child, my father asked me, "If a book came out, what would you write? How about something that changed my life?"\n\nI was a big fan of the story of the New York Times Magazine story about a young man named John Allen, who went on to become one of the most influential authors on the Internet in the early 90s. As he was about to embark on a'}]

# %% [markdown]
# Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
#  → This is perfect for creative dialogue or speculative sci‑fi storytelling

# %%
prompt = "The lucky begger"
print(generator(prompt, max_length=40, temperature=0.6))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The lucky begger of the day was the man who had actually been there before the train had even stopped. He was a man who had been there before the train had actually stopped. He was the lucky one.\n\n"Just as I was about to say something, the train came out of the tunnel and I was in a hurry," he said. "I just got out of the car and started to go straight for the train. It was really hard. I\'m not sure if I could have done it or not."\n\nHe was still in the car when the train came out of the tunnel, but he was holding his breath.\n\nThe train was coming out of the tunnel and he was holding his breath.\n\n"I was in a hurry," he said. "I was out of the car when the train came out of the tunnel and I was in a hurry."\n\nI don\'t know why he was so eager to get off the train. The train was coming out of the tunnel and he was holding his breath.\n\n"I just got out of the car and started to go straight for the train."\n\nHe was still in the car when the train came out of the tunnel and he was holding his breath.\n\n"I'}]
# [{'generated_text': 'The lucky begger," Trump said. "I have a terrific team of people who are doing really great work. And it\'s very nice, and a very nice team of people. But I can\'t say what it\'s. It\'s a good team of people. And I think it\'s very nice. And it\'s very nice."\n\nBut as Trump and the team continue with their daily exchanges, one question remains: What kind of real-life relationships get the media talking about Trump\'s possible presidency?\n\n"You\'ve got to be careful not to be too serious about this, because you\'ve got to keep it going," said Peter Brimelow, president of the nonprofit media watchdog Media Matters for America, which has raised more than $70 million for its work.\n\n"If you\'re going to do a lot of stuff to get attention, you\'ve got to keep going," he added. "And I don\'t think doing the things that are going to get you in trouble are the sort of things that we\'re going to try to do, but I think it\'s going to make it interesting to have other people talking about it."\n\nWhen asked if Trump can bring in some big-name personalities in addition to his staff, Brimelow said'}]

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

prompt = input("Enter a prompt: ")
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Enter a prompt: The future of Artificial Intelligence
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence (AI) is already uncertain. The only system that can truly predict future events is AI. AI is already a problem because of its lack of ability to predict future events.
#
# In the future, AI will be a complex system that only can predict events in a single time frame. For example, a machine that knows the location of the next train will never know if the train is coming from the same station in the same direction as it is in the previous one. This is not to say that AI will be incapable of predicting events in a single time frame, but it is a huge problem for AI and it will never be able to predict events that are much more complex than that.
#
# A computer will always find a way to predict future events. However, even a machine that can predict events in a single time frame is still a problem for AI.
#
# In this article we will look at AIs that are already able to predict future events, but only the future that a computer could predict in one time frame.
#
# The following article covers AIs with the ability to predict future events, but only the future that a computer could predict in one time frame.
#
# In this article, we will look at AIs that have been able to predict

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

prompt = input("Enter a prompt: ")
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Enter a prompt: The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The impact of technology on education was clearly demonstrated in the recent study. An average of 8.9% of students in grades three through 12 are classified as proficient in the English language, compared to 7.2% in grades four through six.
#
# Among the top recipients of the National Science Foundation's grant, a whopping 1.3% of students in grades two through seven are proficient in the English language. Additionally, students in grades four through five are proficient in English, with a higher percentage of students in the fifth- and sixth-grade classes also having a higher percentage of proficient in the language.
#
# The study noted that the overall literacy rate of students in grades five through eight is much lower than the national average.
#
# "A significant number of students in grades five through eight are proficient in the English language," the study said. "This may be because of the limited number of students in grades five through nine who are proficient in the language. Additionally, many students in grades nine through 12 are proficient in the English language, and are more likely to speak the language successfully.
#
# "In spite of the growing number of students in grades five through seven who are proficient in the English language, students in grades eight through 12 are not proficient in the language. These students may be primarily

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output

prompt = input("Enter a prompt: ")
output1 = generator(prompt, max_length=50, temperature=0.6)
output2 = generator(prompt, max_length=50, temperature=0.8)
print(output1[0]["generated_text"])
print('Second output:')
print(output2[0]["generated_text"])
# Out:
# Enter a prompt: Artificial Intelligence will transform
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Intelligence will transform our lives.
#
# This is not a new idea.
#
# In 2008, the National Science Foundation (NSF) announced that it would use artificial intelligence (AI) to develop and "help advance human knowledge of the world."
#
# This was an important step for AI.
#
# But it was also a step too far.
#
# In order to achieve AI, we must keep in mind that we are only beginning to understand the nature of our own reality.
#
# We must not forget that we are not alone in this.
#
# We can not only learn to look at our own world but to learn to look at the world of other people.
#
# We can learn to learn to look at our own world and to learn to look at the world of other people.
#
# We can learn to learn to look at our own world and to learn to look at the world of other people.
#
# We can learn to learn to look at our own world and to learn to look at the world of other people.
#
# And we can learn to learn to look at our own world and to learn to look at the world of other people.
#
# And we can learn to learn to look at our own world and to learn to look at the
# Second output:
# Artificial Intelligence will transform itself from a digital assistant into the digital equivalent of the brain.
#
# This is what's going to be the basis for new products, products that will help us become more connected and to understand who we are, what we value, and to create more value.
#
# One of the issues that I have to address now is if we can't do this right and do it right, how can we do it better?
#
# First of all, we know that the value we want doesn't come from technology, but rather from human beings. If we wanted to get smarter, we could create something that would make us smarter. But it is not going to become that. It's not going to get better.
#
# We are going to get better at it.
#
# This is going to change the world.
#
# I think that we need to start thinking about the future. We need to start thinking about the future.
#
# It's not just about what will happen. It's not just about what will happen now. It's also about what's going to happen in the future.
#
# The future is a very real thing.
#
# I think it's going to be the most important thing in the whole history of this country, so take care

# %% [markdown]
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output

# %%
gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform the way we think about our lives, our lives. We will not only see ourselves as machines, we will learn to think in a way that's more natural and more human.\n\nIn addition to making us more aware of our own needs and emotions, we will be able to better understand and cope with stress, pain and any other kind of pain that comes from living.\n\nOur brains will recognize the need to control and control our emotions, and they will work with us to improve our behavior and our lives.\n\nThis technology will allow us to see beyond our own experiences, and to become more conscious of our emotions and the way our thoughts, actions and actions affect others.\n\nNow, imagine a world in which the ability to control and control our emotions is a huge advantage: we can control the emotions, our behaviors, our relationships, our relationships. We can see our own happiness and joy.\n\nBecause we are already conscious of our emotions, we will be able to see our own happiness and joy in the ways that we think and act.\n\nIn other words, we won't have to treat our emotions like a medical condition. We'll be able to see how our emotions are being treated and treated.\n\nIn other words,"}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the world into a world of information-driven systems, a technology that will enable users to access and navigate their personal information.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.
gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "The future of Artificial Intelligence"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "The future of Artificial Intelligence is very bright indeed, but it seems that some of its potential is beyond our grasp. It is hard to make a prediction as to how fast they will evolve, but they seem to be accelerating, and the future is certainly bright.\n\nI would like to think the future of Artificial Intelligence is bright. I'm not sure we can predict it. But I do think it is going to be interesting to see how things evolve. It is likely that AI will become a very large part of the future of agriculture.\n\nYou can follow me on Twitter and Google+."}]
# DistilGPT2: [{'generated_text': 'The future of Artificial Intelligence\n\n\nThe first step is to get the data that we need. We have a tremendous amount of data, and we have a great amount of data that we need. And it is one of the most important things to know about these things.\nThe first thing we need to know is that we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. and we can build on that in a few years.\nWhat is the next step?\nThis is called the Future of Artificial Intelligence.\nThe Future of Artificial Intelligence\nThis is the next step.\nThe next step is to get the data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need. And we have a great amount of data that we need.'}]
